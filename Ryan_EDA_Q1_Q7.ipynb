# %% [markdown]
# # Email from the boss...
# *I have some questions for you that I need to be answered before the board meeting Thursday afternoon. I need to be able to speak to the following questions. I also need a single slide that I can incorporate into my existing presentation (Google Slides) that summarizes the most important points. My questions are listed below; however, if you discover anything else important that I didn’t think to ask, please include that as well.*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from wrangle import full_wrangle
import warnings
warnings.filterwarnings('ignore')

# reloads import files each time a cell is ranx
# %load_ext autoreload
# %autoreload 2
# Out:
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df, df_staff, df_multicohort, df_unimputed, df_non_curriculum, df_outliers = full_wrangle()
# Out:
# This returned the following dataframes (reassign if you missed any):
#                                                                          Description  \
# Dataframe
# df                                                           Fully cleaned dataframe
# df_staff                                                             Cohort == Staff
# df_multicohort                                  Users listed in more than one cohort
# df_unimputed                                  Users with unknown/unimputable cohorts
# df_non_curriculum  Accessess not related to the curriculum, i.e. directories, images
# df_outliers                                      Accesses meeting outlier conditions
#
#                    Record Count Percent of Raw df
# Dataframe
# df                       509409             56.6%
# df_staff                  84031             9.33%
# df_multicohort            22708             2.52%
# df_unimputed              45904              5.1%
# df_non_curriculum        116539             12.9%
# df_outliers              121626             13.5%

# %% [markdown]
# # Question 1 - Which lesson appears to attract the most traffic consistently across cohorts (per program)?

# %% [markdown]
# First we split the analysis dataframe amongst the two programs:

# %%
df_web = df[df.program_type == 'Web Development']
df_ds = df[df.program_type == 'Data Science']

# %%
df_web.shape, df_ds.shape
# Out:
# ((451039, 11), (58370, 11))

# %% [markdown]
# ## Examining Web Dev:

# %%
df_web.lesson.value_counts().nlargest(10)
# Out:
# Not Lesson                                                                   97362
# mysql.tables                                                                  5477
# javascript-i.introduction.working-with-data-types-operators-and-variables     5312
# mysql.databases                                                               5169
# javascript-i.functions                                                        5163
# javascript-i.javascript-with-html                                             5157
# html-css.elements                                                             5046
# mysql.users                                                                   4858
# html-css.css-ii.bootstrap-grid-system                                         4843
# java-iii.jsp-and-jstl                                                         4840
# Name: lesson, dtype: int64

# %% [markdown]
# *'Not Lesson' are number one, but those represent higher level accesses in the url tree that feed down to the specific lesson.  Those will be ignored.

# %% [markdown]
# Originally took a look at the top 5 lessons overall to see how they tracked through time to find the one with the most traffic.
#
# However, because of name changes of urls, and cohorts with low numbers, this didn't prove to be effective.

# %%
x = pd.crosstab(df_ds.cohort, df_ds.lesson).T

# %%
for n in x.columns:
    print(x[n].nlargest(10))
# Out:
# lesson
# 1-fundamentals.1.1-intro-to-data-science    573
# 6-regression.1-overview                     411
# 10-anomaly-detection.1-overview             289
# 6-regression.5.0-evaluate                   284
# 5-stats.3-probability-distributions         266
# 5-stats.4.2-compare-means                   263
# 6-regression.7.0-model                      257
# Not Lesson                                  253
# 6-regression.4.0-explore                    232
# 4-python.7.4.3-dataframes                   227
# Name: Bayes, dtype: int64
# lesson
# 6-regression.1-overview                     432
# 1-fundamentals.1.1-intro-to-data-science    344
# 3-sql.1-mysql-overview                      333
# 10-anomaly-detection.1-overview             267
# 4-python.8.4.3-dataframes                   205
# 4-python.8.4.4-advanced-dataframes          191
# 4-python.3-data-types-and-variables         177
# 5-stats.4.2-compare-means                   157
# 5-stats.2-simulation                        141
# 3-sql.7-functions                           139
# Name: Curie, dtype: int64
# lesson
# classification.overview                     858
# classification.scale_features_or_not.svg    713
# sql.mysql-overview                          573
# anomaly-detection.overview                  374
# classification.logistic-regression          348
# stats.compare-means                         343
# classification.prep                         318
# 1-fundamentals.1.1-intro-to-data-science    317
# classification.explore                      289
# classification.evaluation                   260
# Name: Darden, dtype: int64
# lesson
# classification.scale_features_or_not.svg    283
# classification.overview                     265
# fundamentals.intro-to-data-science          210
# sql.mysql-overview                          170
# stats.compare-means                         125
# regression.model                            119
# python.advanced-dataframes                  112
# classification.explore                      107
# regression.project                          103
# classification.prep                          99
# Name: Easley, dtype: int64
# lesson
# fundamentals.intro-to-data-science    412
# python.data-types-and-variables       174
# sql.mysql-overview                    146
# sql.joins                             130
# fundamentals.data-science-pipeline    128
# sql.functions                         112
# sql.basic-statements                  108
# sql.mysql-introduction                108
# sql.tables                            105
# fundamentals.git                      103
# Name: Florence, dtype: int64

# %% [markdown]
# ##### I determined the best approach is the use a loop to find the top three lessons for each cohort, then count the occurances of the top lessons.

# %%
wd_cl = df_web.groupby('cohort').lesson.value_counts()

# %%
top_three_wd = []
counter = 0
name = wd_cl.index[0][0]
result_row = {}
for c in wd_cl.index:
    if c[0] != name:
        top_three_wd.append(result_row)
        counter = 0 
        result_row={}
    if counter < 3:
        if c[1] != 'Not Lesson':
            result_row['Cohort'] = c[0]
            result_row[f'#{counter+1} lesson'] = c[1]
            result_row[f'#{counter+1} lesson count'] = wd_cl[c]
            counter += 1
            name = c[0]
    else:
        name = c[0]

# %% [markdown]
# Also, created a function for this:

# %%
import explore_rm

# %%
wd_tl = explore_rm.lesson_top_three(df_web)
wd_tl
# Out:
# Top ten lessons:
# ----------
# Not Lesson                                                                   97362
# mysql.tables                                                                  5477
# javascript-i.introduction.working-with-data-types-operators-and-variables     5312
# mysql.databases                                                               5169
# javascript-i.functions                                                        5163
# javascript-i.javascript-with-html                                             5157
# html-css.elements                                                             5046
# mysql.users                                                                   4858
# html-css.css-ii.bootstrap-grid-system                                         4843
# java-iii.jsp-and-jstl                                                         4840
# Name: lesson, dtype: int64
#         Cohort  \
# 0    Andromeda
# 1         Apex
# 2       Arches
# 3     Badlands
# 4         Bash
# 5   Betelgeuse
# 6        Ceres
# 7       Deimos
# 8       Europa
# 9      Fortuna
# 10    Franklin
# 11    Ganymede
# 12     Glacier
# 13     Hampton
# 14    Hyperion
# 15         Ike
# 16      Joshua
# 17     Jupiter
# 18     Kalypso
# 19       Kings
# 20      Lassen
# 21        Luna
# 22     Mammoth
# 23       Marco
# 24     Neptune
# 25     Niagara
# 26      Oberon
# 27     Olympic
# 28   Pinnacles
# 29      Quincy
# 30     Sequoia
# 31       Teddy
# 32     Ulysses
# 33   Voyageurs
# 34    Wrangell
# 35      Xanadu
# 36    Yosemite
#
#                                                                     #1 lesson  \
# 0   javascript-i.introduction.working-with-data-types-operators-and-variables
# 1                                           java-i.syntax-types-and-variables
# 2                                                          javascript-i.loops
# 3                                                 content.php_ii.command-line
# 4                                                   javascript-i.introduction
# 5                                                           html-css.elements
# 6   javascript-i.introduction.working-with-data-types-operators-and-variables
# 7                                      html-css.css-ii.bootstrap-introduction
# 8                                                           html-css.elements
# 9                                                                mysql.tables
# 10                                                          javascript-ii.es6
# 11                                                          java-iii.servlets
# 12                                                           content.html-css
# 13                                                          java-iii.servlets
# 14                                                          html-css.elements
# 15                                                          html-css.elements
# 16                                                           content.html-css
# 17                                                          java-iii.servlets
# 18                                               javascript-i.bom-and-dom.dom
# 19                                                      content.laravel.intro
# 20                                           spring.fundamentals.repositories
# 21  javascript-i.introduction.working-with-data-types-operators-and-variables
# 22                                            spring.fundamentals.controllers
# 23  javascript-i.introduction.working-with-data-types-operators-and-variables
# 24                                          javascript-i.javascript-with-html
# 25                                                          java-iii.servlets
# 26                                        javascript-i.introduction.operators
# 27                                                           content.html-css
# 28                                                          javascript-ii.npm
# 29                                                      content.laravel.intro
# 30                                                  spring.fundamentals.views
# 31                                                               mysql.tables
# 32                                     spring.fundamentals.form-model-binding
# 33                                                java-i.introduction-to-java
# 34                                      html-css.css-ii.bootstrap-grid-system
# 35                                                          html-css.elements
# 36                                            javascript-ii.map-filter-reduce
#
#     #1 lesson count  \
# 0             263.0
# 1             360.0
# 2              66.0
# 3               6.0
# 4             260.0
# 5             382.0
# 6             372.0
# 7             340.0
# 8             340.0
# 9             303.0
# 10             10.0
# 11            253.0
# 12             14.0
# 13             30.0
# 14            252.0
# 15             11.0
# 16             19.0
# 17            315.0
# 18            283.0
# 19             77.0
# 20            115.0
# 21            226.0
# 22             12.0
# 23            394.0
# 24            153.0
# 25             11.0
# 26             80.0
# 27             50.0
# 28             51.0
# 29             34.0
# 30            169.0
# 31            363.0
# 32            301.0
# 33            420.0
# 34            277.0
# 35            375.0
# 36            232.0
#
#                                                                     #2 lesson  \
# 0                                                                mysql.tables
# 1                                         java-ii.object-oriented-programming
# 2                                                           html-css.elements
# 3                                                               content.php_i
# 4                                           javascript-i.javascript-with-html
# 5                                       html-css.css-ii.bootstrap-grid-system
# 6                                                              html-css.forms
# 7                                       html-css.css-ii.bootstrap-grid-system
# 8                                     html-css.css-i.selectors-and-properties
# 9                                                      mysql.basic-statements
# 10                                                        java-iii.user-input
# 11                                                        java-ii.collections
# 12                                   1-fundamentals.1.1-intro-to-data-science
# 13                                                      java-iii.jsp-and-jstl
# 14                                                      java-iii.jsp-and-jstl
# 15                                                      html-css.introduction
# 16                                         content.html-css.introduction.html
# 17                                        java-ii.object-oriented-programming
# 18                                      html-css.css-ii.bootstrap-grid-system
# 19                                                            content.php_iii
# 20                                                  spring.fundamentals.views
# 21                                                               mysql.tables
# 22                                                  spring.fundamentals.views
# 23                                          javascript-i.javascript-with-html
# 24  javascript-i.introduction.working-with-data-types-operators-and-variables
# 25                                            spring.fundamentals.controllers
# 26                                  javascript-i.introduction.primitive-types
# 27                                                      content.laravel.intro
# 28                                                java-i.introduction-to-java
# 29                                                           content.html-css
# 30                                            spring.fundamentals.controllers
# 31                                                            mysql.databases
# 32                                     html-css.css-ii.bootstrap-introduction
# 33                                                            mysql.databases
# 34                                     html-css.css-ii.bootstrap-introduction
# 35                                                               mysql.tables
# 36                                                               mysql.tables
#
#     #2 lesson count  \
# 0             262.0
# 1             355.0
# 2              65.0
# 3               5.0
# 4             213.0
# 5             341.0
# 6             353.0
# 7             324.0
# 8             299.0
# 9             286.0
# 10              3.0
# 11            233.0
# 12              7.0
# 13             27.0
# 14            236.0
# 15             10.0
# 16             14.0
# 17            313.0
# 18            248.0
# 19             45.0
# 20            100.0
# 21            143.0
# 22             11.0
# 23            300.0
# 24             91.0
# 25             11.0
# 26             72.0
# 27             31.0
# 28             29.0
# 29             26.0
# 30            149.0
# 31            356.0
# 32            259.0
# 33            395.0
# 34            275.0
# 35            336.0
# 36            224.0
#
#                                                                     #3 lesson  \
# 0                                            spring.fundamentals.repositories
# 1                                                                mysql.tables
# 2                                                      javascript-ii.promises
# 3                                         content.php_ii.control-structures-i
# 4   javascript-i.introduction.working-with-data-types-operators-and-variables
# 5                                           javascript-i.javascript-with-html
# 6                                                           html-css.elements
# 7                                                                mysql.tables
# 8                                                                mysql.tables
# 9                                                       java-iii.jsp-and-jstl
# 10                                                javascript-i.coffee-project
# 11                                        java-ii.object-oriented-programming
# 12                                         content.html-css.introduction.html
# 13                                                              java-iii.jdbc
# 14                                                          java-iii.servlets
# 15                                                             html-css.forms
# 16                                               content.mysql.intro-to-mysql
# 17                                                               mysql.tables
# 18                                                      java-iii.jsp-and-jstl
# 19                                                             content.php_iv
# 20                                                      java-iii.jsp-and-jstl
# 21                                                         javascript-i.loops
# 22                                                              content.php_i
# 23                                                     javascript-i.functions
# 24                                                         javascript-i.loops
# 25                                            javascript-ii.map-filter-reduce
# 26  javascript-i.introduction.working-with-data-types-operators-and-variables
# 27                                         content.html-css.introduction.html
# 28                                                     javascript-ii.promises
# 29                                                            content.php_iii
# 30                                     spring.fundamentals.form-model-binding
# 31                                                                mysql.users
# 32                                                                mysql.users
# 33                                                               mysql.tables
# 34                                                     javascript-i.functions
# 35                                                            mysql.databases
# 36                                                     mysql.basic-statements
#
#     #3 lesson count
# 0             259.0
# 1             348.0
# 2              63.0
# 3               5.0
# 4             211.0
# 5             274.0
# 6             351.0
# 7             311.0
# 8             285.0
# 9             275.0
# 10              2.0
# 11            231.0
# 12              7.0
# 13             24.0
# 14            229.0
# 15              8.0
# 16             10.0
# 17            312.0
# 18            210.0
# 19             40.0
# 20             93.0
# 21            141.0
# 22              9.0
# 23            296.0
# 24             84.0
# 25              9.0
# 26             66.0
# 27             30.0
# 28             28.0
# 29             16.0
# 30            144.0
# 31            338.0
# 32            248.0
# 33            387.0
# 34            271.0
# 35            298.0
# 36            189.0

# %%
a1 = wd_tl['#1 lesson'].value_counts()
b1 = wd_tl['#2 lesson'].value_counts()
c1 = wd_tl['#3 lesson'].value_counts() 
(a1 + b1 + c1).nlargest()
# Out:
# mysql.tables                                                                 11.0
# html-css.elements                                                             7.0
# javascript-i.introduction.working-with-data-types-operators-and-variables     7.0
# javascript-i.javascript-with-html                                             4.0
# dtype: float64

# %% [markdown]
# ##### mysql.tables was the most accessed overall, and is the most consistently high amongst the cohorts.

# %% [markdown]
# ### *Looking at unit:*

# %% [markdown]
# Created a function that creates a unit column from the path and applied it to the web analysis dataframe.

# %%
wd_tu = explore_rm.unit_top_three(df_web)
wd_tu
# Out:
# Top ten units:
# ----------
# javascript-i     83241
# html-css         59975
# mysql            59947
# jquery           43066
# java-iii         39998
# spring           39982
# java-ii          38903
# java-i           29129
# javascript-ii    27918
# examples          9765
# Name: unit, dtype: int64
#         Cohort        #1 unit  #1 unit count         #2 unit  #2 unit count  \
# 0    Andromeda   javascript-i           3554        html-css           2598
# 1         Apex   javascript-i           4175           mysql           3741
# 2       Arches   javascript-i            921        html-css            626
# 3     Badlands        content             57         prework              6
# 4         Bash   javascript-i           3108        html-css           2141
# 5   Betelgeuse   javascript-i           3952        html-css           2564
# 6        Ceres   javascript-i           5794        html-css           5115
# 7       Deimos   javascript-i           4444        html-css           4346
# 8       Europa       html-css           3029    javascript-i           2918
# 9      Fortuna   javascript-i           3969           mysql           3335
# 10    Franklin  javascript-ii             13        java-iii             11
# 11    Ganymede   javascript-i           3569        html-css           2759
# 12     Glacier        content             88  1-fundamentals              7
# 13     Hampton       java-iii            210          spring            157
# 14    Hyperion   javascript-i           3151           mysql           2311
# 15         Ike       html-css             56         content             53
# 16      Joshua        content            217      index.html              5
# 17     Jupiter   javascript-i           3919           mysql           3282
# 18     Kalypso   javascript-i           3225        html-css           2265
# 19       Kings        content           2052      index.html             84
# 20      Lassen         spring           1071         content           1037
# 21        Luna   javascript-i           2274           mysql           1512
# 22     Mammoth        content            240          spring             50
# 23       Marco   javascript-i           4390        html-css           2624
# 24     Neptune   javascript-i           1030        html-css            837
# 25     Niagara         spring            139        java-iii             72
# 26      Oberon   javascript-i            534          jquery              4
# 27     Olympic        content            820    javascript-i            128
# 28   Pinnacles   javascript-i            240   javascript-ii            220
# 29      Quincy        content            469           mysql             97
# 30     Sequoia         spring           1413    javascript-i            876
# 31       Teddy          mysql           3992    javascript-i           3577
# 32     Ulysses   javascript-i           2929           mysql           2381
# 33   Voyageurs   javascript-i           4326           mysql           4125
# 34    Wrangell   javascript-i           3807        html-css           2673
# 35      Xanadu   javascript-i           3920           mysql           3467
# 36    Yosemite   javascript-i           2446           mysql           2133
#
#           #3 unit  #3 unit count
# 0           mysql           2521
# 1        html-css           3452
# 2   javascript-ii            445
# 3   javascript-ii              5
# 4           mysql           2054
# 5          jquery           2205
# 6           mysql           3765
# 7           mysql           3567
# 8           mysql           2913
# 9        html-css           3196
# 10   javascript-i              8
# 11          mysql           2726
# 12         java-i              3
# 13          mysql            137
# 14       html-css           2117
# 15   javascript-i             33
# 16        prework              4
# 17       java-iii           2920
# 18          mysql           1761
# 19   javascript-i             61
# 20   javascript-i            997
# 21       html-css           1391
# 22       java-iii             47
# 23         jquery           1975
# 24       examples            131
# 25          mysql             58
# 26       html-css              3
# 27         java-i             59
# 28          mysql            194
# 29         java-i             50
# 30       html-css            714
# 31         spring           2839
# 32       html-css           2207
# 33       html-css           2936
# 34          mysql           2139
# 35       html-css           2818
# 36       html-css           1689

# %%
a2 = wd_tu['#1 unit'].value_counts()
b2 = wd_tu['#2 unit'].value_counts()
c2 = wd_tu['#3 unit'].value_counts() 
(a2 + b2 + c2).nlargest()
# Out:
# javascript-i    30.0
# html-css        23.0
# mysql           22.0
# spring           6.0
# java-iii         5.0
# dtype: float64

# %% [markdown]
# ##### From a unit standpoint, javascript-i is the most accessed unit across curriculums, with mysql third.
# ### Overall, I would say "mysql/tables" is the most accessed lesson.

# %% [markdown]
# ## Examing DS

# %%
ds_tl = explore_rm.lesson_top_three(df_ds)
ds_tl
# Out:
# Top ten lessons:
# ----------
# classification.overview                     1310
# 1-fundamentals.1.1-intro-to-data-science    1270
# classification.scale_features_or_not.svg    1138
# sql.mysql-overview                          1008
# fundamentals.intro-to-data-science           946
# 6-regression.1-overview                      848
# 10-anomaly-detection.1-overview              573
# 3-sql.1-mysql-overview                       543
# anomaly-detection.overview                   523
# stats.compare-means                          510
# Name: lesson, dtype: int64
#    Cohort                                 #1 lesson  #1 lesson count  \
# 0   Bayes  1-fundamentals.1.1-intro-to-data-science              573
# 1   Curie                   6-regression.1-overview              432
# 2  Darden                   classification.overview              858
# 3  Easley  classification.scale_features_or_not.svg              283
#
#                                   #2 lesson  #2 lesson count  \
# 0                   6-regression.1-overview              411
# 1  1-fundamentals.1.1-intro-to-data-science              344
# 2  classification.scale_features_or_not.svg              713
# 3                   classification.overview              265
#
#                             #3 lesson  #3 lesson count
# 0     10-anomaly-detection.1-overview              289
# 1              3-sql.1-mysql-overview              333
# 2                  sql.mysql-overview              573
# 3  fundamentals.intro-to-data-science              210

# %%
a3 = ds_tl['#1 lesson'].value_counts()
b3 = ds_tl['#2 lesson'].value_counts()
c3 = ds_tl['#3 lesson'].value_counts()
(a3 + b3 + c3).nlargest()
# Out:
# Series([], dtype: float64)

# %% [markdown]
# This did not work because it counts missing values as NaNs that wipe the whole row out.  Looking just at columns 1 and two:

# %%
(a3 + b3)
# Out:
# 1-fundamentals.1.1-intro-to-data-science    2
# 6-regression.1-overview                     2
# classification.overview                     2
# classification.scale_features_or_not.svg    2
# dtype: int64

# %% [markdown]
# ##### Classification Overview is the is the highest overall, and also scores high across cohorts with introduction/fundamentals close behind.  Interestingly, an image ranked very highly - the svg - means it must be a very good image (not a lesson).  Regression overview and into also rank highly.
# Interesting note: It seems the path syntax changed from Bayes to Easely, as evidenced by the fundamentals having two seperate high scoring lessons.

# %% [markdown]
# ### *Looking at unit:*

# %%
ds_tu = explore_rm.unit_top_three(df_ds)
ds_tu
# Out:
# Top ten units:
# ----------
# classification      5993
# sql                 5239
# 3-sql               4819
# python              4078
# 4-python            3793
# 6-regression        3523
# fundamentals        3462
# 1-fundamentals      3079
# 5-stats             2732
# 7-classification    2476
# Name: unit, dtype: int64
#    Cohort         #1 unit  #1 unit count   #2 unit  #2 unit count  \
# 0   Bayes    6-regression           2121  4-python           2031
# 1   Curie           3-sql           1897  4-python           1682
# 2  Darden  classification           3991    python           2051
# 3  Easley  classification           1348       sql           1169
#
#         #3 unit  #3 unit count
# 0         3-sql           1927
# 1  6-regression           1381
# 2           sql           2046
# 3  fundamentals            915

# %%
a4 = ds_tu['#1 unit'].value_counts()
b4 = ds_tu['#2 unit'].value_counts()
c4 = ds_tu['#3 unit'].value_counts()
(a4 + b4 + c4).nlargest()
# Out:
# Series([], dtype: float64)

# %% [markdown]
# Also did not work since missing values wipe out the additions.  But overallthe two sql units, when combined, appear to have the highest number of accesses.

# %% [markdown]
# ##### While the sql unit has the most number of accesses overall, there are also a lot of lessons within sql.
# ### Overall, I would say the "classification/overview" lesson is the most accessed.

# %% [markdown]
# ## 7. Which lessons are least accessed?

# %% [markdown]
# There are lots of lessons with just a few accesses (many with just 1).  Therefore, we focused on unit for this question.

# %% [markdown]
# ### Web:

# %%
web_units = df_web.groupby('cohort').unit.nunique().index
web_units
# Out:
# Index(['Andromeda', 'Apex', 'Arches', 'Badlands', 'Bash', 'Betelgeuse',
#        'Ceres', 'Deimos', 'Europa', 'Fortuna', 'Franklin', 'Ganymede',
#        'Glacier', 'Hampton', 'Hyperion', 'Ike', 'Joshua', 'Jupiter', 'Kalypso',
#        'Kings', 'Lassen', 'Luna', 'Mammoth', 'Marco', 'Neptune', 'Niagara',
#        'Oberon', 'Olympic', 'Pinnacles', 'Quincy', 'Sequoia', 'Teddy',
#        'Ulysses', 'Voyageurs', 'Wrangell', 'Xanadu', 'Yosemite', 'Zion'],
#       dtype='object', name='cohort')

# %%
setter = df_web[df_web.cohort == "Andromeda"].lesson.unique()
for i in web_units:
    unit_list = df_web[df_web.cohort == i].lesson.unique()
    setter = list(set(setter).intersection(unit_list)) 
setter
# Out:
# ['Not Lesson']

# %%
df_web.unit.value_counts()[df_web.unit.value_counts()>50].nsmallest(10)
# Out:
# introduction        52
# git                 52
# elements            54
# 1-fundamentals      62
# prework            695
# index.html        1080
# web-design        1407
# capstone          1847
# slides            5993
# content           6576
# Name: unit, dtype: int64

# %% [markdown]
# ##### Not counting prework (or the index) I would say the least accessed unit in general is 'web-design'

# %%
setter = df_web[df_web.cohort == "Andromeda"].lesson.unique()
for i in web_units:
    unit_list = df_web[df_web.cohort == i].lesson.unique()
    setter = list(set(setter).intersection(unit_list)) 
setter
# Out:
# ['Not Lesson']

# %% [markdown]
# ### Data Science

# %%
ds_units = df_ds.groupby('cohort').unit.nunique().index

# %%
setter = df_ds[df_ds.cohort == "Bayes"].unit.unique()
for i in ds_units:
    unit_list = df_ds[df_ds.cohort == i].unit.unique()
    setter = list(set(setter).intersection(unit_list)) 
setter
# Out:
# ['sql',
#  'regression',
#  'classification',
#  'capstones',
#  'anomaly-detection',
#  'fundamentals',
#  'python',
#  'storytelling',
#  'distributed-ml',
#  'nlp',
#  'timeseries',
#  'clustering',
#  '1-fundamentals',
#  'stats']

# %%
df_ds.unit.value_counts()[df_ds.unit.value_counts()>50]
# Out:
# classification          5993
# sql                     5239
# 3-sql                   4819
# python                  4078
# 4-python                3793
# 6-regression            3523
# fundamentals            3462
# 1-fundamentals          3079
# 5-stats                 2732
# 7-classification        2476
# stats                   2423
# regression              2093
# 11-nlp                  1536
# 8-clustering            1463
# 9-timeseries            1401
# clustering              1325
# 2-storytelling          1188
# timeseries              1113
# 10-anomaly-detection    1099
# storytelling             998
# nlp                      973
# anomaly-detection        892
# 12-distributed-ml        818
# 13-advanced-topics       798
# distributed-ml           425
# advanced-topics          117
# Name: unit, dtype: int64

# %% [markdown]
# ##### Distributed ML seems to be the elast accessed.

# %%
asdf = df_ds.groupby('cohort').lesson.nunique().index

# %%
setter = df_ds[df_ds.cohort == "Bayes"].lesson.unique()
for i in asdf:
    unit_list = df_ds[df_ds.cohort == i].lesson.unique()
    setter = list(set(setter).intersection(unit_list)) 
setter
# Out:
# ['python.data-types-and-variables',
#  'python.imports',
#  '1-fundamentals.1.1-intro-to-data-science',
#  'classification.decision-trees',
#  'stats.probability-distributions',
#  'classification.explore',
#  'fundamentals.visualization-with-excel',
#  'sql.more-exercises',
#  'python.dataframes',
#  'classification.prep',
#  'classification.scale_features_or_not.svg',
#  'anomaly-detection.overview',
#  'fundamentals.data-science-pipeline',
#  'storytelling.understand',
#  'fundamentals.functions',
#  'classification.acquire',
#  'sql.tables',
#  'stats.simulation',
#  'fundamentals.vocabulary',
#  'python.advanced-dataframes',
#  'fundamentals.cli.more-topics',
#  'fundamentals.git',
#  'storytelling.create',
#  'python.pandas-overview',
#  'sql.limit',
#  'capstones.capstones',
#  'fundamentals.spreadsheets-overview',
#  'regression.project',
#  'classification.evaluation',
#  'sql.indexes',
#  'fundamentals.environment-setup',
#  'python.intro-to-matplotlib',
#  'timeseries.overview',
#  'fundamentals.cli.listing-files',
#  'regression.overview',
#  'sql.mysql-introduction',
#  'classification.project',
#  'storytelling.connecting-to-data',
#  'python.series',
#  'classification.overview',
#  'stats.overview',
#  'python.ds-libraries-overview',
#  'sql.group-by',
#  'sql.mysql-overview',
#  'fundamentals.cli.intro',
#  'sql.order-by',
#  'fundamentals.pipeline-demo',
#  'sql.clauses-overview',
#  'python.functions',
#  'sql.database-design',
#  'python.control-structures',
#  'regression.feature-engineering',
#  'classification.logistic-regression',
#  'python.intro-to-numpy',
#  'python.introduction-to-python',
#  'fundamentals.intro-to-data-science',
#  'nlp.overview',
#  'fundamentals.cli.file-paths',
#  'sql.temporary-tables',
#  'storytelling.overview',
#  'sql.databases',
#  'sql.relationships-overview',
#  'classification.tidy-data',
#  'sql.basic-statements',
#  'Not Lesson',
#  'fundamentals.cli.creating-files-and-directories',
#  'fundamentals.cli.moving-files',
#  'sql.joins',
#  'sql.functions',
#  'python.intro-to-seaborn',
#  'sql.case-statements',
#  'sql.subqueries',
#  'fundamentals.cli.navigating-the-filesystem',
#  'nlp.regular-expressions',
#  'storytelling.tableau',
#  'sql.where',
#  'storytelling.creating-charts',
#  'clustering.overview',
#  'regression.explore',
#  'python.overview']

# %%
qw = []
for n in setter:
    row = {}
    row['Lesson'] = n
    row['Count'] = df[df.lesson == n].accessed.count()
    qw.append(row)
pd.DataFrame(qw).set_index('Lesson').Count.nsmallest(10)
# Out:
# Lesson
# capstones.capstones                                46
# storytelling.creating-charts                       56
# fundamentals.cli.more-topics                       60
# fundamentals.cli.moving-files                      70
# storytelling.connecting-to-data                    78
# nlp.overview                                       79
# fundamentals.cli.navigating-the-filesystem         82
# fundamentals.cli.file-paths                        83
# fundamentals.cli.creating-files-and-directories    93
# storytelling.tableau                               96
# Name: Count, dtype: int64

# %% [markdown]
# Capstones is the smallest

# %% [markdown]
# ----
